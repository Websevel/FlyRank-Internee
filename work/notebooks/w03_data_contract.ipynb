# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Websevel/FlyRank-Internee/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*
#
# For your lane (content decline/refresh), one row is one content item, on one report date, for one client. That's the grain of fact_content_daily_performance

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*
#
# Almost certainly fact_content_daily_performance (or its _sample for mechanics-only testing), possibly joined to dim_content for content-level attributes and dim_clients for client metadata.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*
#
# Grain check: GROUP BY <your row-defining columns> HAVING COUNT(*) > 1 → should return empty. This proves your "one row = X" claim from Step 1 wasn't wishful thinking.
# Row count + date span: COUNT(*), MIN(report_date), MAX(report_date) for your slice. Confirms you're actually looking at what you think you're looking at.
# Availability: filter with ga4_data_available IS TRUE (or whichever flag applies to your columns) and show how many rows survive vs. the unfiltered count. This matters because — per the panel warning — rows before a client's GA4 start date are zero-filled, not genuinely zero, so skipping this filter would quietly corrupt anything downstream

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*
#
#
#   Add one column that's derived from your label as a "feature" — e.g., if your label is decline-based, sneak in something like trend_pct itself or a column computed after the outcome.
# Train a tiny/quick model or compute a quick score. Watch it jump toward suspiciously perfect.
# Delete the leaked column, rerun, and keep the honest (lower, real) number.
# Show both numbers in the notebook — the inflated one and the honest one — so the before/after is visible, not just described.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
